# %%
import gymnasium as gym
from stable_baselines3 import SAC, TD3, A2C
import os
import argparse
# Out:
# 2025-03-20 10:00:08.748241: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE3 SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# Create directories to hold models and logs
model_dir = f"models"
log_dir = f"logs"
os.makedirs(model_dir, exist_ok=True)
os.makedirs(log_dir, exist_ok=True)

def train(model, timesteps, ):

    

    iters = 0
    while True:
        iters += 1
        model.learn(total_timesteps=timesteps, reset_num_timesteps=False)
        model.save(f"{model_dir}/SACv1_{model.num_timesteps - model.num_timesteps % 1000}")
    return model

# def test(env, sb3_algo, path_to_model):

#     match sb3_algo:
#         case 'SAC':
#             model = SAC.load(path_to_model, env=env)
#         case 'TD3':
#             model = TD3.load(path_to_model, env=env)
#         case 'A2C':
#             model = A2C.load(path_to_model, env=env)
#         case _:
#             print('Algorithm not found')
#             return

#     obs = env.reset()[0]
#     done = False
#     extra_steps = 500
#     while True:
#         action, _ = model.predict(obs)
#         obs, _, done, _, _ = env.step(action)

#         if done:
#             extra_steps -= 1

#             if extra_steps < 0:
#                 break

    # parser = argparse.ArgumentParser(description='Train or test model.')
    # parser.add_argument('gymenv', help='Gymnasium environment i.e. Humanoid-v4')
    # parser.add_argument('sb3_algo', help='StableBaseline3 RL algorithm i.e. SAC, TD3')
    # parser.add_argument('-t', '--train', action='store_true')
    # parser.add_argument('-s', '--test', metavar='path_to_model')
    # args = parser.parse_args()

# %%
env = gym.make("Humanoid-v5", render_mode=None)

# %%
model = SAC('MlpPolicy', env, verbose=1, device='cuda', tensorboard_log=log_dir)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
model = SAC.load("models/SAC_736000", verbose=1, device='cuda', tensorboard_log=log_dir)
model.set_env(env)
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
model = train(model, 20000)
# Out:
# Logging to logs/SAC_0
# /home/vardan/anaconda3/envs/pytorch/lib/python3.10/site-packages/torch/nn/modules/linear.py:125: UserWarning: Attempting to use hipBLASLt on an unsupported architecture! Overriding blas backend to hipblas (Triggered internally at /pytorch/aten/src/ATen/Context.cpp:310.)
#   return F.linear(input, self.weight, self.bias)
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 758      |
# |    ep_rew_mean     | 4.12e+03 |
# | time/              |          |
# |    episodes        | 2612     |
# |    fps             | 31       |
# |    time_elapsed    | 10       |
# |    total_timesteps | 736434   |
# | train/             |          |
# |    actor_loss      | -259     |
# |    critic_loss     | 46.4     |
# |    ent_coef        | 0.0452   |
# |    ent_coef_loss   | 31.6     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 736332   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 738      |
# |    ep_rew_mean     | 4.01e+03 |
# | time/              |          |
# |    episodes        | 2616     |
# |    fps             | 33       |
# |    time_elapsed    | 21       |
# |    total_timesteps | 736823   |
# | train/             |          |
# |    actor_loss      | -284     |
# |    critic_loss     | 47.3     |
# |    ent_coef        | 0.051    |
# |    ent_coef_loss   | 19.2     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 736721   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 712      |
# |    ep_rew_mean     | 3.87e+03 |
# | time/              |          |
# |    episodes        | 2620     |
# |    fps             | 33       |
# |    time_elapsed    | 31       |
# |    total_timesteps | 737168   |
# | train/             |          |
# |    actor_loss      | -274     |
# |    critic_loss     | 54.8     |
# |    ent_coef        | 0.0554   |
# |    ent_coef_loss   | 9.08     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 737066   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 684      |
# |    ep_rew_mean     | 3.72e+03 |
# | time/              |          |
# |    episodes        | 2624     |
# |    fps             | 33       |
# |    time_elapsed    | 42       |
# |    total_timesteps | 737542   |
# | train/             |          |
# |    actor_loss      | -280     |
# |    critic_loss     | 33       |
# |    ent_coef        | 0.0595   |
# |    ent_coef_loss   | 12.2     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 737440   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 660      |
# |    ep_rew_mean     | 3.58e+03 |
# | time/              |          |
# |    episodes        | 2628     |
# |    fps             | 34       |
# |    time_elapsed    | 50       |
# |    total_timesteps | 737826   |
# | train/             |          |
# |    actor_loss      | -300     |
# |    critic_loss     | 33.9     |
# |    ent_coef        | 0.0636   |
# |    ent_coef_loss   | 10.9     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 737724   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 636      |
# |    ep_rew_mean     | 3.45e+03 |
# | time/              |          |
# |    episodes        | 2632     |
# |    fps             | 34       |
# |    time_elapsed    | 63       |
# |    total_timesteps | 738289   |
# | train/             |          |
# |    actor_loss      | -279     |
# |    critic_loss     | 49.6     |
# |    ent_coef        | 0.0691   |
# |    ent_coef_loss   | 8.64     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 738187   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 618      |
# |    ep_rew_mean     | 3.35e+03 |
# | time/              |          |
# |    episodes        | 2636     |
# |    fps             | 34       |
# |    time_elapsed    | 72       |
# |    total_timesteps | 738595   |
# | train/             |          |
# |    actor_loss      | -292     |
# |    critic_loss     | 76.7     |
# |    ent_coef        | 0.0734   |
# |    ent_coef_loss   | 9.65     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 738493   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 588      |
# |    ep_rew_mean     | 3.18e+03 |
# | time/              |          |
# |    episodes        | 2640     |
# |    fps             | 34       |
# |    time_elapsed    | 77       |
# |    total_timesteps | 738788   |
# | train/             |          |
# |    actor_loss      | -306     |
# |    critic_loss     | 27.9     |
# |    ent_coef        | 0.0767   |
# |    ent_coef_loss   | 8.27     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 738686   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 562      |
# |    ep_rew_mean     | 3.04e+03 |
# | time/              |          |
# |    episodes        | 2644     |
# |    fps             | 34       |
# |    time_elapsed    | 85       |
# |    total_timesteps | 739068   |
# | train/             |          |
# |    actor_loss      | -285     |
# |    critic_loss     | 46.1     |
# |    ent_coef        | 0.0809   |
# |    ent_coef_loss   | 5.12     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 738966   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 542      |
# |    ep_rew_mean     | 2.93e+03 |
# | time/              |          |
# |    episodes        | 2648     |
# |    fps             | 34       |
# |    time_elapsed    | 94       |
# |    total_timesteps | 739386   |
# | train/             |          |
# |    actor_loss      | -292     |
# |    critic_loss     | 38.5     |
# |    ent_coef        | 0.0857   |
# |    ent_coef_loss   | 6.62     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 739284   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 509      |
# |    ep_rew_mean     | 2.75e+03 |
# | time/              |          |
# |    episodes        | 2652     |
# |    fps             | 34       |
# |    time_elapsed    | 108      |
# |    total_timesteps | 739859   |
# | train/             |          |
# |    actor_loss      | -295     |
# |    critic_loss     | 43.4     |
# |    ent_coef        | 0.091    |
# |    ent_coef_loss   | 0.362    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 739757   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 477      |
# |    ep_rew_mean     | 2.58e+03 |
# | time/              |          |
# |    episodes        | 2656     |
# |    fps             | 34       |
# |    time_elapsed    | 118      |
# |    total_timesteps | 740206   |
# | train/             |          |
# |    actor_loss      | -301     |
# |    critic_loss     | 62.5     |
# |    ent_coef        | 0.0936   |
# |    ent_coef_loss   | 2.02     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 740104   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 446      |
# |    ep_rew_mean     | 2.41e+03 |
# | time/              |          |
# |    episodes        | 2660     |
# |    fps             | 34       |
# |    time_elapsed    | 129      |
# |    total_timesteps | 740589   |
# | train/             |          |
# |    actor_loss      | -288     |
# |    critic_loss     | 188      |
# |    ent_coef        | 0.0958   |
# |    ent_coef_loss   | -0.456   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 740487   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 429      |
# |    ep_rew_mean     | 2.31e+03 |
# | time/              |          |
# |    episodes        | 2664     |
# |    fps             | 34       |
# |    time_elapsed    | 141      |
# |    total_timesteps | 740998   |
# | train/             |          |
# |    actor_loss      | -292     |
# |    critic_loss     | 76       |
# |    ent_coef        | 0.0975   |
# |    ent_coef_loss   | 2.16     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 740896   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 395      |
# |    ep_rew_mean     | 2.13e+03 |
# | time/              |          |
# |    episodes        | 2668     |
# |    fps             | 34       |
# |    time_elapsed    | 155      |
# |    total_timesteps | 741445   |
# | train/             |          |
# |    actor_loss      | -296     |
# |    critic_loss     | 76.8     |
# |    ent_coef        | 0.0988   |
# |    ent_coef_loss   | 0.32     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 741343   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 360      |
# |    ep_rew_mean     | 1.93e+03 |
# | time/              |          |
# |    episodes        | 2672     |
# |    fps             | 34       |
# |    time_elapsed    | 164      |
# |    total_timesteps | 741759   |
# | train/             |          |
# |    actor_loss      | -305     |
# |    critic_loss     | 78.5     |
# |    ent_coef        | 0.101    |
# |    ent_coef_loss   | -1.5     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 741657   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 324      |
# |    ep_rew_mean     | 1.73e+03 |
# | time/              |          |
# |    episodes        | 2676     |
# |    fps             | 34       |
# |    time_elapsed    | 175      |
# |    total_timesteps | 742144   |
# | train/             |          |
# |    actor_loss      | -305     |
# |    critic_loss     | 41.1     |
# |    ent_coef        | 0.0999   |
# |    ent_coef_loss   | 1.83     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 742042   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 293      |
# |    ep_rew_mean     | 1.56e+03 |
# | time/              |          |
# |    episodes        | 2680     |
# |    fps             | 34       |
# |    time_elapsed    | 186      |
# |    total_timesteps | 742520   |
# | train/             |          |
# |    actor_loss      | -281     |
# |    critic_loss     | 113      |
# |    ent_coef        | 0.101    |
# |    ent_coef_loss   | 2.3      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 742418   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 263      |
# |    ep_rew_mean     | 1.4e+03  |
# | time/              |          |
# |    episodes        | 2684     |
# |    fps             | 34       |
# |    time_elapsed    | 194      |
# |    total_timesteps | 742778   |
# | train/             |          |
# |    actor_loss      | -298     |
# |    critic_loss     | 71.8     |
# |    ent_coef        | 0.102    |
# |    ent_coef_loss   | 0.354    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 742676   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 237      |
# |    ep_rew_mean     | 1.25e+03 |
# | time/              |          |
# |    episodes        | 2688     |
# |    fps             | 34       |
# |    time_elapsed    | 205      |
# |    total_timesteps | 743159   |
# | train/             |          |
# |    actor_loss      | -282     |
# |    critic_loss     | 62.8     |
# |    ent_coef        | 0.104    |
# |    ent_coef_loss   | 2.78     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 743057   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 216      |
# |    ep_rew_mean     | 1.14e+03 |
# | time/              |          |
# |    episodes        | 2692     |
# |    fps             | 34       |
# |    time_elapsed    | 214      |
# |    total_timesteps | 743505   |
# | train/             |          |
# |    actor_loss      | -295     |
# |    critic_loss     | 71.6     |
# |    ent_coef        | 0.105    |
# |    ent_coef_loss   | -0.245   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 743403   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 184      |
# |    ep_rew_mean     | 957      |
# | time/              |          |
# |    episodes        | 2696     |
# |    fps             | 34       |
# |    time_elapsed    | 224      |
# |    total_timesteps | 743908   |
# | train/             |          |
# |    actor_loss      | -299     |
# |    critic_loss     | 161      |
# |    ent_coef        | 0.107    |
# |    ent_coef_loss   | -1.67    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 743806   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 155      |
# |    ep_rew_mean     | 796      |
# | time/              |          |
# |    episodes        | 2700     |
# |    fps             | 34       |
# |    time_elapsed    | 238      |
# |    total_timesteps | 744375   |
# | train/             |          |
# |    actor_loss      | -282     |
# |    critic_loss     | 87.9     |
# |    ent_coef        | 0.107    |
# |    ent_coef_loss   | -0.045   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 744273   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 130      |
# |    ep_rew_mean     | 661      |
# | time/              |          |
# |    episodes        | 2704     |
# |    fps             | 34       |
# |    time_elapsed    | 259      |
# |    total_timesteps | 745072   |
# | train/             |          |
# |    actor_loss      | -289     |
# |    critic_loss     | 90.4     |
# |    ent_coef        | 0.107    |
# |    ent_coef_loss   | 2.52     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 744970   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 94.7     |
# |    ep_rew_mean     | 471      |
# | time/              |          |
# |    episodes        | 2708     |
# |    fps             | 34       |
# |    time_elapsed    | 273      |
# |    total_timesteps | 745576   |
# | train/             |          |
# |    actor_loss      | -292     |
# |    critic_loss     | 76.8     |
# |    ent_coef        | 0.106    |
# |    ent_coef_loss   | -0.865   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 745474   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 95.1     |
# |    ep_rew_mean     | 471      |
# | time/              |          |
# |    episodes        | 2712     |
# |    fps             | 34       |
# |    time_elapsed    | 284      |
# |    total_timesteps | 745940   |
# | train/             |          |
# |    actor_loss      | -307     |
# |    critic_loss     | 78.1     |
# |    ent_coef        | 0.105    |
# |    ent_coef_loss   | -0.452   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 745838   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 94.3     |
# |    ep_rew_mean     | 466      |
# | time/              |          |
# |    episodes        | 2716     |
# |    fps             | 34       |
# |    time_elapsed    | 293      |
# |    total_timesteps | 746258   |
# | train/             |          |
# |    actor_loss      | -284     |
# |    critic_loss     | 79.6     |
# |    ent_coef        | 0.104    |
# |    ent_coef_loss   | 0.429    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 746156   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 95.5     |
# |    ep_rew_mean     | 469      |
# | time/              |          |
# |    episodes        | 2720     |
# |    fps             | 34       |
# |    time_elapsed    | 306      |
# |    total_timesteps | 746717   |
# | train/             |          |
# |    actor_loss      | -297     |
# |    critic_loss     | 119      |
# |    ent_coef        | 0.104    |
# |    ent_coef_loss   | -2.94    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 746615   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 95.2     |
# |    ep_rew_mean     | 464      |
# | time/              |          |
# |    episodes        | 2724     |
# |    fps             | 34       |
# |    time_elapsed    | 315      |
# |    total_timesteps | 747066   |
# | train/             |          |
# |    actor_loss      | -295     |
# |    critic_loss     | 115      |
# |    ent_coef        | 0.103    |
# |    ent_coef_loss   | 0.312    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 746964   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 97.1     |
# |    ep_rew_mean     | 472      |
# | time/              |          |
# |    episodes        | 2728     |
# |    fps             | 35       |
# |    time_elapsed    | 326      |
# |    total_timesteps | 747532   |
# | train/             |          |
# |    actor_loss      | -306     |
# |    critic_loss     | 92.9     |
# |    ent_coef        | 0.103    |
# |    ent_coef_loss   | 3.58     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 747430   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 97.5     |
# |    ep_rew_mean     | 472      |
# | time/              |          |
# |    episodes        | 2732     |
# |    fps             | 34       |
# |    time_elapsed    | 341      |
# |    total_timesteps | 748035   |
# | train/             |          |
# |    actor_loss      | -310     |
# |    critic_loss     | 154      |
# |    ent_coef        | 0.105    |
# |    ent_coef_loss   | 0.0873   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 747933   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 97.9     |
# |    ep_rew_mean     | 474      |
# | time/              |          |
# |    episodes        | 2736     |
# |    fps             | 34       |
# |    time_elapsed    | 351      |
# |    total_timesteps | 748383   |
# | train/             |          |
# |    actor_loss      | -297     |
# |    critic_loss     | 97.7     |
# |    ent_coef        | 0.106    |
# |    ent_coef_loss   | -1.49    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 748281   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 98.5     |
# |    ep_rew_mean     | 477      |
# | time/              |          |
# |    episodes        | 2740     |
# |    fps             | 34       |
# |    time_elapsed    | 358      |
# |    total_timesteps | 748637   |
# | train/             |          |
# |    actor_loss      | -316     |
# |    critic_loss     | 106      |
# |    ent_coef        | 0.107    |
# |    ent_coef_loss   | 2.52     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 748535   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 98.6     |
# |    ep_rew_mean     | 478      |
# | time/              |          |
# |    episodes        | 2744     |
# |    fps             | 34       |
# |    time_elapsed    | 367      |
# |    total_timesteps | 748932   |
# | train/             |          |
# |    actor_loss      | -294     |
# |    critic_loss     | 83.6     |
# |    ent_coef        | 0.108    |
# |    ent_coef_loss   | -0.351   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 748830   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 98.2     |
# |    ep_rew_mean     | 475      |
# | time/              |          |
# |    episodes        | 2748     |
# |    fps             | 34       |
# |    time_elapsed    | 375      |
# |    total_timesteps | 749202   |
# | train/             |          |
# |    actor_loss      | -296     |
# |    critic_loss     | 171      |
# |    ent_coef        | 0.109    |
# |    ent_coef_loss   | -0.857   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 749100   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 96.4     |
# |    ep_rew_mean     | 466      |
# | time/              |          |
# |    episodes        | 2752     |
# |    fps             | 34       |
# |    time_elapsed    | 383      |
# |    total_timesteps | 749499   |
# | train/             |          |
# |    actor_loss      | -303     |
# |    critic_loss     | 158      |
# |    ent_coef        | 0.109    |
# |    ent_coef_loss   | -2.03    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 749397   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 94.8     |
# |    ep_rew_mean     | 457      |
# | time/              |          |
# |    episodes        | 2756     |
# |    fps             | 34       |
# |    time_elapsed    | 389      |
# |    total_timesteps | 749684   |
# | train/             |          |
# |    actor_loss      | -308     |
# |    critic_loss     | 147      |
# |    ent_coef        | 0.11     |
# |    ent_coef_loss   | -0.74    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 749582   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 94.6     |
# |    ep_rew_mean     | 457      |
# | time/              |          |
# |    episodes        | 2760     |
# |    fps             | 34       |
# |    time_elapsed    | 399      |
# |    total_timesteps | 750049   |
# | train/             |          |
# |    actor_loss      | -288     |
# |    critic_loss     | 174      |
# |    ent_coef        | 0.113    |
# |    ent_coef_loss   | 0.532    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 749947   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 92.8     |
# |    ep_rew_mean     | 447      |
# | time/              |          |
# |    episodes        | 2764     |
# |    fps             | 34       |
# |    time_elapsed    | 405      |
# |    total_timesteps | 750277   |
# | train/             |          |
# |    actor_loss      | -287     |
# |    critic_loss     | 150      |
# |    ent_coef        | 0.114    |
# |    ent_coef_loss   | -0.53    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 750175   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 92.2     |
# |    ep_rew_mean     | 443      |
# | time/              |          |
# |    episodes        | 2768     |
# |    fps             | 35       |
# |    time_elapsed    | 414      |
# |    total_timesteps | 750666   |
# | train/             |          |
# |    actor_loss      | -295     |
# |    critic_loss     | 308      |
# |    ent_coef        | 0.112    |
# |    ent_coef_loss   | -3.24    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 750564   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 92.6     |
# |    ep_rew_mean     | 444      |
# | time/              |          |
# |    episodes        | 2772     |
# |    fps             | 35       |
# |    time_elapsed    | 424      |
# |    total_timesteps | 751021   |
# | train/             |          |
# |    actor_loss      | -291     |
# |    critic_loss     | 125      |
# |    ent_coef        | 0.11     |
# |    ent_coef_loss   | -1.59    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 750919   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 91.5     |
# |    ep_rew_mean     | 438      |
# | time/              |          |
# |    episodes        | 2776     |
# |    fps             | 35       |
# |    time_elapsed    | 432      |
# |    total_timesteps | 751297   |
# | train/             |          |
# |    actor_loss      | -286     |
# |    critic_loss     | 136      |
# |    ent_coef        | 0.109    |
# |    ent_coef_loss   | -1.96    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 751195   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 92.3     |
# |    ep_rew_mean     | 443      |
# | time/              |          |
# |    episodes        | 2780     |
# |    fps             | 35       |
# |    time_elapsed    | 445      |
# |    total_timesteps | 751747   |
# | train/             |          |
# |    actor_loss      | -285     |
# |    critic_loss     | 125      |
# |    ent_coef        | 0.108    |
# |    ent_coef_loss   | 1.36     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 751645   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 93.5     |
# |    ep_rew_mean     | 450      |
# | time/              |          |
# |    episodes        | 2784     |
# |    fps             | 35       |
# |    time_elapsed    | 456      |
# |    total_timesteps | 752125   |
# | train/             |          |
# |    actor_loss      | -263     |
# |    critic_loss     | 168      |
# |    ent_coef        | 0.108    |
# |    ent_coef_loss   | 2.59     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 752023   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 94.6     |
# |    ep_rew_mean     | 456      |
# | time/              |          |
# |    episodes        | 2788     |
# |    fps             | 35       |
# |    time_elapsed    | 471      |
# |    total_timesteps | 752616   |
# | train/             |          |
# |    actor_loss      | -276     |
# |    critic_loss     | 187      |
# |    ent_coef        | 0.107    |
# |    ent_coef_loss   | -2.76    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 752514   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 94.9     |
# |    ep_rew_mean     | 458      |
# | time/              |          |
# |    episodes        | 2792     |
# |    fps             | 34       |
# |    time_elapsed    | 482      |
# |    total_timesteps | 752994   |
# | train/             |          |
# |    actor_loss      | -292     |
# |    critic_loss     | 153      |
# |    ent_coef        | 0.108    |
# |    ent_coef_loss   | -2.53    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 752892   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 96.2     |
# |    ep_rew_mean     | 467      |
# | time/              |          |
# |    episodes        | 2796     |
# |    fps             | 34       |
# |    time_elapsed    | 498      |
# |    total_timesteps | 753523   |
# | train/             |          |
# |    actor_loss      | -306     |
# |    critic_loss     | 120      |
# |    ent_coef        | 0.105    |
# |    ent_coef_loss   | -0.826   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 753421   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 95.8     |
# |    ep_rew_mean     | 467      |
# | time/              |          |
# |    episodes        | 2800     |
# |    fps             | 34       |
# |    time_elapsed    | 510      |
# |    total_timesteps | 753950   |
# | train/             |          |
# |    actor_loss      | -275     |
# |    critic_loss     | 128      |
# |    ent_coef        | 0.107    |
# |    ent_coef_loss   | -1.79    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 753848   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 93.3     |
# |    ep_rew_mean     | 455      |
# | time/              |          |
# |    episodes        | 2804     |
# |    fps             | 34       |
# |    time_elapsed    | 524      |
# |    total_timesteps | 754398   |
# | train/             |          |
# |    actor_loss      | -284     |
# |    critic_loss     | 222      |
# |    ent_coef        | 0.106    |
# |    ent_coef_loss   | 3.77     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 754296   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 93.7     |
# |    ep_rew_mean     | 458      |
# | time/              |          |
# |    episodes        | 2808     |
# |    fps             | 34       |
# |    time_elapsed    | 539      |
# |    total_timesteps | 754941   |
# | train/             |          |
# |    actor_loss      | -273     |
# |    critic_loss     | 244      |
# |    ent_coef        | 0.106    |
# |    ent_coef_loss   | -0.481   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 754839   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 98.1     |
# |    ep_rew_mean     | 482      |
# | time/              |          |
# |    episodes        | 2812     |
# |    fps             | 34       |
# |    time_elapsed    | 563      |
# |    total_timesteps | 755747   |
# | train/             |          |
# |    actor_loss      | -286     |
# |    critic_loss     | 122      |
# |    ent_coef        | 0.105    |
# |    ent_coef_loss   | 1.87     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 755645   |
# ---------------------------------
# Logging to logs/SAC_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 98.9     |
# |    ep_rew_mean     | 488      |
# | time/              |          |
# |    episodes        | 2816     |
# |    fps             | 36       |
# |    time_elapsed    | 1        |
# |    total_timesteps | 756146   |
# | train/             |          |
# |    actor_loss      | -281     |
# |    critic_loss     | 140      |
# |    ent_coef        | 0.104    |
# |    ent_coef_loss   | -2.2     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 756044   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 98.7     |
# |    ep_rew_mean     | 488      |
# | time/              |          |
# |    episodes        | 2820     |
# |    fps             | 34       |
# |    time_elapsed    | 13       |
# |    total_timesteps | 756589   |
# | train/             |          |
# |    actor_loss      | -273     |
# |    critic_loss     | 120      |
# |    ent_coef        | 0.102    |
# |    ent_coef_loss   | -2.16    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 756487   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 101      |
# |    ep_rew_mean     | 499      |
# | time/              |          |
# |    episodes        | 2824     |
# |    fps             | 34       |
# |    time_elapsed    | 29       |
# |    total_timesteps | 757136   |
# | train/             |          |
# |    actor_loss      | -268     |
# |    critic_loss     | 175      |
# |    ent_coef        | 0.101    |
# |    ent_coef_loss   | 1.98     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 757034   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 102      |
# |    ep_rew_mean     | 507      |
# | time/              |          |
# |    episodes        | 2828     |
# |    fps             | 34       |
# |    time_elapsed    | 47       |
# |    total_timesteps | 757741   |
# | train/             |          |
# |    actor_loss      | -272     |
# |    critic_loss     | 129      |
# |    ent_coef        | 0.103    |
# |    ent_coef_loss   | -2.13    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 757639   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 102      |
# |    ep_rew_mean     | 508      |
# | time/              |          |
# |    episodes        | 2832     |
# |    fps             | 34       |
# |    time_elapsed    | 60       |
# |    total_timesteps | 758192   |
# | train/             |          |
# |    actor_loss      | -289     |
# |    critic_loss     | 121      |
# |    ent_coef        | 0.103    |
# |    ent_coef_loss   | -1.25    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 758090   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 102      |
# |    ep_rew_mean     | 513      |
# | time/              |          |
# |    episodes        | 2836     |
# |    fps             | 36       |
# |    time_elapsed    | 69       |
# |    total_timesteps | 758622   |
# | train/             |          |
# |    actor_loss      | -267     |
# |    critic_loss     | 107      |
# |    ent_coef        | 0.103    |
# |    ent_coef_loss   | 1.85     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 758520   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 106      |
# |    ep_rew_mean     | 527      |
# | time/              |          |
# |    episodes        | 2840     |
# |    fps             | 38       |
# |    time_elapsed    | 81       |
# |    total_timesteps | 759202   |
# | train/             |          |
# |    actor_loss      | -264     |
# |    critic_loss     | 166      |
# |    ent_coef        | 0.103    |
# |    ent_coef_loss   | 0.455    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 759100   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 108      |
# |    ep_rew_mean     | 537      |
# | time/              |          |
# |    episodes        | 2844     |
# |    fps             | 40       |
# |    time_elapsed    | 89       |
# |    total_timesteps | 759698   |
# | train/             |          |
# |    actor_loss      | -269     |
# |    critic_loss     | 158      |
# |    ent_coef        | 0.104    |
# |    ent_coef_loss   | 1.71     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 759596   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 110      |
# |    ep_rew_mean     | 547      |
# | time/              |          |
# |    episodes        | 2848     |
# |    fps             | 41       |
# |    time_elapsed    | 97       |
# |    total_timesteps | 760167   |
# | train/             |          |
# |    actor_loss      | -266     |
# |    critic_loss     | 133      |
# |    ent_coef        | 0.103    |
# |    ent_coef_loss   | -1.65    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 760065   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 112      |
# |    ep_rew_mean     | 556      |
# | time/              |          |
# |    episodes        | 2852     |
# |    fps             | 43       |
# |    time_elapsed    | 106      |
# |    total_timesteps | 760674   |
# | train/             |          |
# |    actor_loss      | -270     |
# |    critic_loss     | 119      |
# |    ent_coef        | 0.1      |
# |    ent_coef_loss   | -0.529   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 760572   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 116      |
# |    ep_rew_mean     | 576      |
# | time/              |          |
# |    episodes        | 2856     |
# |    fps             | 43       |
# |    time_elapsed    | 118      |
# |    total_timesteps | 761289   |
# | train/             |          |
# |    actor_loss      | -266     |
# |    critic_loss     | 95.9     |
# |    ent_coef        | 0.0977   |
# |    ent_coef_loss   | 0.365    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 761187   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 118      |
# |    ep_rew_mean     | 583      |
# | time/              |          |
# |    episodes        | 2860     |
# |    fps             | 43       |
# |    time_elapsed    | 133      |
# |    total_timesteps | 761843   |
# | train/             |          |
# |    actor_loss      | -245     |
# |    critic_loss     | 142      |
# |    ent_coef        | 0.0974   |
# |    ent_coef_loss   | -1.18    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 761741   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 119      |
# |    ep_rew_mean     | 587      |
# | time/              |          |
# |    episodes        | 2864     |
# |    fps             | 42       |
# |    time_elapsed    | 142      |
# |    total_timesteps | 762157   |
# | train/             |          |
# |    actor_loss      | -249     |
# |    critic_loss     | 132      |
# |    ent_coef        | 0.0983   |
# |    ent_coef_loss   | -1.43    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 762055   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 593      |
# | time/              |          |
# |    episodes        | 2868     |
# |    fps             | 41       |
# |    time_elapsed    | 157      |
# |    total_timesteps | 762697   |
# | train/             |          |
# |    actor_loss      | -253     |
# |    critic_loss     | 140      |
# |    ent_coef        | 0.0972   |
# |    ent_coef_loss   | 0.688    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 762595   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 592      |
# | time/              |          |
# |    episodes        | 2872     |
# |    fps             | 41       |
# |    time_elapsed    | 168      |
# |    total_timesteps | 763048   |
# | train/             |          |
# |    actor_loss      | -257     |
# |    critic_loss     | 255      |
# |    ent_coef        | 0.096    |
# |    ent_coef_loss   | 1.35     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 762946   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 123      |
# |    ep_rew_mean     | 603      |
# | time/              |          |
# |    episodes        | 2876     |
# |    fps             | 40       |
# |    time_elapsed    | 184      |
# |    total_timesteps | 763588   |
# | train/             |          |
# |    actor_loss      | -256     |
# |    critic_loss     | 159      |
# |    ent_coef        | 0.0968   |
# |    ent_coef_loss   | 3.94     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 763486   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 123      |
# |    ep_rew_mean     | 602      |
# | time/              |          |
# |    episodes        | 2880     |
# |    fps             | 40       |
# |    time_elapsed    | 195      |
# |    total_timesteps | 764045   |
# | train/             |          |
# |    actor_loss      | -253     |
# |    critic_loss     | 136      |
# |    ent_coef        | 0.0961   |
# |    ent_coef_loss   | -3.2     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 763943   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 124      |
# |    ep_rew_mean     | 607      |
# | time/              |          |
# |    episodes        | 2884     |
# |    fps             | 40       |
# |    time_elapsed    | 211      |
# |    total_timesteps | 764573   |
# | train/             |          |
# |    actor_loss      | -250     |
# |    critic_loss     | 140      |
# |    ent_coef        | 0.0954   |
# |    ent_coef_loss   | 0.799    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 764471   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 126      |
# |    ep_rew_mean     | 614      |
# | time/              |          |
# |    episodes        | 2888     |
# |    fps             | 39       |
# |    time_elapsed    | 229      |
# |    total_timesteps | 765198   |
# | train/             |          |
# |    actor_loss      | -255     |
# |    critic_loss     | 154      |
# |    ent_coef        | 0.0961   |
# |    ent_coef_loss   | 1.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 765096   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 129      |
# |    ep_rew_mean     | 631      |
# | time/              |          |
# |    episodes        | 2892     |
# |    fps             | 39       |
# |    time_elapsed    | 250      |
# |    total_timesteps | 765911   |
# | train/             |          |
# |    actor_loss      | -237     |
# |    critic_loss     | 155      |
# |    ent_coef        | 0.0954   |
# |    ent_coef_loss   | 2.02     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 765809   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 128      |
# |    ep_rew_mean     | 626      |
# | time/              |          |
# |    episodes        | 2896     |
# |    fps             | 38       |
# |    time_elapsed    | 263      |
# |    total_timesteps | 766368   |
# | train/             |          |
# |    actor_loss      | -250     |
# |    critic_loss     | 134      |
# |    ent_coef        | 0.094    |
# |    ent_coef_loss   | -4.29    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 766266   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 127      |
# |    ep_rew_mean     | 619      |
# | time/              |          |
# |    episodes        | 2900     |
# |    fps             | 38       |
# |    time_elapsed    | 272      |
# |    total_timesteps | 766654   |
# | train/             |          |
# |    actor_loss      | -256     |
# |    critic_loss     | 177      |
# |    ent_coef        | 0.0934   |
# |    ent_coef_loss   | 0.718    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 766552   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 127      |
# |    ep_rew_mean     | 616      |
# | time/              |          |
# |    episodes        | 2904     |
# |    fps             | 38       |
# |    time_elapsed    | 283      |
# |    total_timesteps | 767049   |
# | train/             |          |
# |    actor_loss      | -229     |
# |    critic_loss     | 129      |
# |    ent_coef        | 0.0934   |
# |    ent_coef_loss   | -1.17    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 766947   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 125      |
# |    ep_rew_mean     | 606      |
# | time/              |          |
# |    episodes        | 2908     |
# |    fps             | 38       |
# |    time_elapsed    | 293      |
# |    total_timesteps | 767399   |
# | train/             |          |
# |    actor_loss      | -243     |
# |    critic_loss     | 210      |
# |    ent_coef        | 0.092    |
# |    ent_coef_loss   | -0.715   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 767297   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 584      |
# | time/              |          |
# |    episodes        | 2912     |
# |    fps             | 38       |
# |    time_elapsed    | 304      |
# |    total_timesteps | 767751   |
# | train/             |          |
# |    actor_loss      | -247     |
# |    critic_loss     | 131      |
# |    ent_coef        | 0.0918   |
# |    ent_coef_loss   | 1.06     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 767649   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 122      |
# |    ep_rew_mean     | 595      |
# | time/              |          |
# |    episodes        | 2916     |
# |    fps             | 38       |
# |    time_elapsed    | 322      |
# |    total_timesteps | 768355   |
# | train/             |          |
# |    actor_loss      | -247     |
# |    critic_loss     | 166      |
# |    ent_coef        | 0.0908   |
# |    ent_coef_loss   | 1.22     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 768253   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 121      |
# |    ep_rew_mean     | 592      |
# | time/              |          |
# |    episodes        | 2920     |
# |    fps             | 38       |
# |    time_elapsed    | 330      |
# |    total_timesteps | 768704   |
# | train/             |          |
# |    actor_loss      | -239     |
# |    critic_loss     | 142      |
# |    ent_coef        | 0.0889   |
# |    ent_coef_loss   | -0.276   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 768602   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 588      |
# | time/              |          |
# |    episodes        | 2924     |
# |    fps             | 38       |
# |    time_elapsed    | 342      |
# |    total_timesteps | 769120   |
# | train/             |          |
# |    actor_loss      | -235     |
# |    critic_loss     | 139      |
# |    ent_coef        | 0.0869   |
# |    ent_coef_loss   | -0.961   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 769018   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 117      |
# |    ep_rew_mean     | 573      |
# | time/              |          |
# |    episodes        | 2928     |
# |    fps             | 37       |
# |    time_elapsed    | 351      |
# |    total_timesteps | 769429   |
# | train/             |          |
# |    actor_loss      | -233     |
# |    critic_loss     | 146      |
# |    ent_coef        | 0.0848   |
# |    ent_coef_loss   | 3.19     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 769327   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 114      |
# |    ep_rew_mean     | 559      |
# | time/              |          |
# |    episodes        | 2932     |
# |    fps             | 37       |
# |    time_elapsed    | 355      |
# |    total_timesteps | 769601   |
# | train/             |          |
# |    actor_loss      | -231     |
# |    critic_loss     | 111      |
# |    ent_coef        | 0.0848   |
# |    ent_coef_loss   | -1.63    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 769499   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 112      |
# |    ep_rew_mean     | 551      |
# | time/              |          |
# |    episodes        | 2936     |
# |    fps             | 38       |
# |    time_elapsed    | 359      |
# |    total_timesteps | 769845   |
# | train/             |          |
# |    actor_loss      | -242     |
# |    critic_loss     | 193      |
# |    ent_coef        | 0.0848   |
# |    ent_coef_loss   | -1.98    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 769743   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 109      |
# |    ep_rew_mean     | 539      |
# | time/              |          |
# |    episodes        | 2940     |
# |    fps             | 38       |
# ...
# |    ent_coef_loss   | 0.0888   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2162500  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 976      |
# |    ep_rew_mean     | 5.86e+03 |
# | time/              |          |
# |    episodes        | 4968     |
# |    fps             | 36       |
# |    time_elapsed    | 273      |
# |    total_timesteps | 2166206  |
# | train/             |          |
# |    actor_loss      | -549     |
# |    critic_loss     | 20.3     |
# |    ent_coef        | 0.0147   |
# |    ent_coef_loss   | 9.21     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2166104  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 962      |
# |    ep_rew_mean     | 5.78e+03 |
# | time/              |          |
# |    episodes        | 4972     |
# |    fps             | 36       |
# |    time_elapsed    | 345      |
# |    total_timesteps | 2168811  |
# | train/             |          |
# |    actor_loss      | -555     |
# |    critic_loss     | 10.6     |
# |    ent_coef        | 0.0142   |
# |    ent_coef_loss   | -14      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2168709  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 954      |
# |    ep_rew_mean     | 5.73e+03 |
# | time/              |          |
# |    episodes        | 4976     |
# |    fps             | 40       |
# |    time_elapsed    | 396      |
# |    total_timesteps | 2171991  |
# | train/             |          |
# |    actor_loss      | -555     |
# |    critic_loss     | 11       |
# |    ent_coef        | 0.0148   |
# |    ent_coef_loss   | -2.23    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2171889  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 945      |
# |    ep_rew_mean     | 5.67e+03 |
# | time/              |          |
# |    episodes        | 4980     |
# |    fps             | 39       |
# |    time_elapsed    | 480      |
# |    total_timesteps | 2175103  |
# | train/             |          |
# |    actor_loss      | -551     |
# |    critic_loss     | 14.2     |
# |    ent_coef        | 0.0151   |
# |    ent_coef_loss   | -2.74    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2175001  |
# ---------------------------------
# Logging to logs/SAC_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 939      |
# |    ep_rew_mean     | 5.64e+03 |
# | time/              |          |
# |    episodes        | 4984     |
# |    fps             | 49       |
# |    time_elapsed    | 48       |
# |    total_timesteps | 2178487  |
# | train/             |          |
# |    actor_loss      | -550     |
# |    critic_loss     | 32.5     |
# |    ent_coef        | 0.0162   |
# |    ent_coef_loss   | -4.36    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2178385  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 939      |
# |    ep_rew_mean     | 5.64e+03 |
# | time/              |          |
# |    episodes        | 4988     |
# |    fps             | 39       |
# |    time_elapsed    | 161      |
# |    total_timesteps | 2182487  |
# | train/             |          |
# |    actor_loss      | -551     |
# |    critic_loss     | 16.8     |
# |    ent_coef        | 0.0167   |
# |    ent_coef_loss   | 0.151    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2182385  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 939      |
# |    ep_rew_mean     | 5.64e+03 |
# | time/              |          |
# |    episodes        | 4992     |
# |    fps             | 37       |
# |    time_elapsed    | 276      |
# |    total_timesteps | 2186487  |
# | train/             |          |
# |    actor_loss      | -551     |
# |    critic_loss     | 10.8     |
# |    ent_coef        | 0.0159   |
# |    ent_coef_loss   | -5.97    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2186385  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 939      |
# |    ep_rew_mean     | 5.64e+03 |
# | time/              |          |
# |    episodes        | 4996     |
# |    fps             | 36       |
# |    time_elapsed    | 390      |
# |    total_timesteps | 2190487  |
# | train/             |          |
# |    actor_loss      | -550     |
# |    critic_loss     | 9.39     |
# |    ent_coef        | 0.0159   |
# |    ent_coef_loss   | -5.68    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2190385  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 939      |
# |    ep_rew_mean     | 5.64e+03 |
# | time/              |          |
# |    episodes        | 5000     |
# |    fps             | 36       |
# |    time_elapsed    | 503      |
# |    total_timesteps | 2194487  |
# | train/             |          |
# |    actor_loss      | -551     |
# |    critic_loss     | 20.1     |
# |    ent_coef        | 0.0154   |
# |    ent_coef_loss   | -0.394   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2194385  |
# ---------------------------------
# Logging to logs/SAC_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 939      |
# |    ep_rew_mean     | 5.64e+03 |
# | time/              |          |
# |    episodes        | 5004     |
# |    fps             | 35       |
# |    time_elapsed    | 67       |
# |    total_timesteps | 2198487  |
# | train/             |          |
# |    actor_loss      | -550     |
# |    critic_loss     | 14.2     |
# |    ent_coef        | 0.016    |
# |    ent_coef_loss   | 10.7     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2198385  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 932      |
# |    ep_rew_mean     | 5.59e+03 |
# | time/              |          |
# |    episodes        | 5008     |
# |    fps             | 35       |
# |    time_elapsed    | 159      |
# |    total_timesteps | 2201759  |
# | train/             |          |
# |    actor_loss      | -553     |
# |    critic_loss     | 13.5     |
# |    ent_coef        | 0.0152   |
# |    ent_coef_loss   | 3.22     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2201657  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 934      |
# |    ep_rew_mean     | 5.61e+03 |
# | time/              |          |
# |    episodes        | 5012     |
# |    fps             | 35       |
# |    time_elapsed    | 259      |
# |    total_timesteps | 2205284  |
# | train/             |          |
# |    actor_loss      | -542     |
# |    critic_loss     | 16.5     |
# |    ent_coef        | 0.0147   |
# |    ent_coef_loss   | -1.46    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2205182  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 934      |
# |    ep_rew_mean     | 5.61e+03 |
# | time/              |          |
# |    episodes        | 5016     |
# |    fps             | 35       |
# |    time_elapsed    | 374      |
# |    total_timesteps | 2209284  |
# | train/             |          |
# |    actor_loss      | -549     |
# |    critic_loss     | 21.5     |
# |    ent_coef        | 0.0155   |
# |    ent_coef_loss   | -0.613   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2209182  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 934      |
# |    ep_rew_mean     | 5.61e+03 |
# | time/              |          |
# |    episodes        | 5020     |
# |    fps             | 35       |
# |    time_elapsed    | 488      |
# |    total_timesteps | 2213284  |
# | train/             |          |
# |    actor_loss      | -551     |
# |    critic_loss     | 12.6     |
# |    ent_coef        | 0.0164   |
# |    ent_coef_loss   | 0.583    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2213182  |
# ---------------------------------
# Logging to logs/SAC_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 934      |
# |    ep_rew_mean     | 5.61e+03 |
# | time/              |          |
# |    episodes        | 5024     |
# |    fps             | 35       |
# |    time_elapsed    | 33       |
# |    total_timesteps | 2217284  |
# | train/             |          |
# |    actor_loss      | -547     |
# |    critic_loss     | 9.11     |
# |    ent_coef        | 0.0158   |
# |    ent_coef_loss   | -8.75    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2217182  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 934      |
# |    ep_rew_mean     | 5.61e+03 |
# | time/              |          |
# |    episodes        | 5028     |
# |    fps             | 35       |
# |    time_elapsed    | 147      |
# |    total_timesteps | 2221284  |
# | train/             |          |
# |    actor_loss      | -547     |
# |    critic_loss     | 34.8     |
# |    ent_coef        | 0.0155   |
# |    ent_coef_loss   | -2.78    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2221182  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 934      |
# |    ep_rew_mean     | 5.62e+03 |
# | time/              |          |
# |    episodes        | 5032     |
# |    fps             | 35       |
# |    time_elapsed    | 261      |
# |    total_timesteps | 2225284  |
# | train/             |          |
# |    actor_loss      | -545     |
# |    critic_loss     | 13.3     |
# |    ent_coef        | 0.0157   |
# |    ent_coef_loss   | 8.93     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2225182  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 934      |
# |    ep_rew_mean     | 5.62e+03 |
# | time/              |          |
# |    episodes        | 5036     |
# |    fps             | 34       |
# |    time_elapsed    | 376      |
# |    total_timesteps | 2229284  |
# | train/             |          |
# |    actor_loss      | -553     |
# |    critic_loss     | 10       |
# |    ent_coef        | 0.0159   |
# |    ent_coef_loss   | 2.78     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2229182  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 934      |
# |    ep_rew_mean     | 5.62e+03 |
# | time/              |          |
# |    episodes        | 5040     |
# |    fps             | 35       |
# |    time_elapsed    | 480      |
# |    total_timesteps | 2233284  |
# | train/             |          |
# |    actor_loss      | -550     |
# |    critic_loss     | 15.2     |
# |    ent_coef        | 0.0147   |
# |    ent_coef_loss   | 7.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2233182  |
# ---------------------------------
# Logging to logs/SAC_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 934      |
# |    ep_rew_mean     | 5.62e+03 |
# | time/              |          |
# |    episodes        | 5044     |
# |    fps             | 37       |
# |    time_elapsed    | 31       |
# |    total_timesteps | 2237284  |
# | train/             |          |
# |    actor_loss      | -548     |
# |    critic_loss     | 17.6     |
# |    ent_coef        | 0.0138   |
# |    ent_coef_loss   | 6.39     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2237182  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 931      |
# |    ep_rew_mean     | 5.6e+03  |
# | time/              |          |
# |    episodes        | 5048     |
# |    fps             | 37       |
# |    time_elapsed    | 127      |
# |    total_timesteps | 2240913  |
# | train/             |          |
# |    actor_loss      | -549     |
# |    critic_loss     | 22.4     |
# |    ent_coef        | 0.0146   |
# |    ent_coef_loss   | -1.33    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2240811  |
# ---------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 model = train(model, 20000)
#
# Cell In[2], line 14, in train(model, timesteps)
#      12 while True:
#      13     iters += 1
# ---> 14     model.learn(total_timesteps=timesteps, reset_num_timesteps=False)
#      15     model.save(f"{model_dir}/SAC_{model.num_timesteps - model.num_timesteps % 1000}")
#      16 return model
#
# File ~/anaconda3/envs/pytorch/lib/python3.10/site-packages/stable_baselines3/sac/sac.py:307, in SAC.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     298 def learn(
#     299     self: SelfSAC,
#     300     total_timesteps: int,
#    (...)
#     305     progress_bar: bool = False,
#     306 ) -> SelfSAC:
# --> 307     return super().learn(
#     308         total_timesteps=total_timesteps,
#     309         callback=callback,
#     310         log_interval=log_interval,
#     311         tb_log_name=tb_log_name,
#     312         reset_num_timesteps=reset_num_timesteps,
#     313         progress_bar=progress_bar,
#     314     )
#
# File ~/anaconda3/envs/pytorch/lib/python3.10/site-packages/stable_baselines3/common/off_policy_algorithm.py:347, in OffPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     345         # Special case when the user passes `gradient_steps=0`
#     346         if gradient_steps > 0:
# --> 347             self.train(batch_size=self.batch_size, gradient_steps=gradient_steps)
#     349 callback.on_training_end()
#     351 return self
#
# File ~/anaconda3/envs/pytorch/lib/python3.10/site-packages/stable_baselines3/sac/sac.py:280, in SAC.train(self, gradient_steps, batch_size)
#     278 # Optimize the actor
#     279 self.actor.optimizer.zero_grad()
# --> 280 actor_loss.backward()
#     281 self.actor.optimizer.step()
#     283 # Update target networks
#
# File ~/anaconda3/envs/pytorch/lib/python3.10/site-packages/torch/_tensor.py:626, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     616 if has_torch_function_unary(self):
#     617     return handle_torch_function(
#     618         Tensor.backward,
#     619         (self,),
#    (...)
#     624         inputs=inputs,
#     625     )
# --> 626 torch.autograd.backward(
#     627     self, gradient, retain_graph, create_graph, inputs=inputs
#     628 )
#
# File ~/anaconda3/envs/pytorch/lib/python3.10/site-packages/torch/autograd/__init__.py:347, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     342     retain_graph = create_graph
#     344 # The reason we repeat the same comment below is that
#     345 # some Python versions print out the first line of a multi-line function
#     346 # calls in the traceback and some print out the last line
# --> 347 _engine_run_backward(
#     348     tensors,
#     349     grad_tensors_,
#     350     retain_graph,
#     351     create_graph,
#     352     inputs,
#     353     allow_unreachable=True,
#     354     accumulate_grad=True,
#     355 )
#
# File ~/anaconda3/envs/pytorch/lib/python3.10/site-packages/torch/autograd/graph.py:823, in _engine_run_backward(t_outputs, *args, **kwargs)
#     821     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     822 try:
# --> 823     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     824         t_outputs, *args, **kwargs
#     825     )  # Calls into the C++ engine to run the backward pass
#     826 finally:
#     827     if attach_logging_hooks:
#
# KeyboardInterrupt:

# %%
model.save("models/SAC_1")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 model.save("models/SAC_1")
#
# NameError: name 'model' is not defined
